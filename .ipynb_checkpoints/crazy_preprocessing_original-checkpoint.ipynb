# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
tqdm.pandas()
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV
from scipy.stats.stats import pearsonr

# %%
train_df=pd.read_csv('./Data/train.csv')

# %%
train_df.head()
# Out:
#    id      y  var1 var2 var3   t1_2001   t2_2001   t3_2001   t4_2001  \
# 0   1  113.0    19    A    A -0.140642 -0.388162 -0.574181 -0.583770
# 1   2  119.0    14    C    A  0.023754 -0.105455 -0.245025 -0.310670
# 2   3  109.0    13    A    A  0.180818  0.135004  0.001879 -0.134548
# 3   4  110.0    18    A    A -0.234780 -0.094543  0.193084  0.508519
# 4   5  123.0    32    A    A -0.130934 -0.360313 -0.547045 -0.603495
#
#     t5_2001  ...  t106_9170  t107_9170  t108_9170  t109_9170  t110_9170  \
# 0 -0.376220  ...   0.584130  -0.100278  -0.846640  -1.461938  -1.801008
# 1 -0.249384  ...  -3.024336  -2.480266  -1.118005   0.181451   0.726820
# 2 -0.185928  ...  -0.156851  -0.262902  -0.668436  -1.172372  -1.387328
# 3  0.668783  ...  -1.358540  -0.028478   0.535346  -0.116384  -1.542395
# 4 -0.508025  ...  -0.825535  -0.392556   0.156361   0.567142   0.756362
#
#    t111_9170  t112_9170  t113_9170  t114_9170  t115_9170
# 0  -1.804553  -1.500023  -0.980571  -0.377526   0.168243
# 1   0.401501  -0.356744  -0.913405  -0.854943  -0.193468
# 2  -1.016077  -0.103130   0.935900   1.550512   1.405350
# 3  -2.486781  -1.631185   1.481241   6.015514  10.233163
# 4   0.809336   0.844580   0.876423   0.801686   0.524566
#
# [5 rows x 13345 columns]

# %%
train_df[train_df['y']==100]
# Out:
#       id      y  var1 var2 var3   t1_2001   t2_2001   t3_2001   t4_2001  \
# 12    13  100.0    21    A    A  0.124419 -0.032010 -0.163048 -0.229382
# 28    34  100.0    21    A    C  0.115065  0.101137  0.074821  0.030425
# 40    48  100.0    17    A    C  0.022479  0.256213  0.465878  0.504451
# 43    52  100.0    15    C    C -0.023276 -0.195995 -0.311649 -0.323039
# 64    88  100.0    15    A    C  1.096983 -2.115259 -5.090382 -5.179050
# 69    96  100.0    14    A    A  3.409460  4.971033  3.714782  0.286575
# 72   100  100.0    16    A    A -3.202108 -4.036236 -1.983144  1.376994
# 121  172  100.0    17    A    C -0.356160 -0.612644 -0.175026  0.923642
# 176  245  100.0    19    A    C -0.426139 -0.587009 -0.290303  0.193842
# 198  275  100.0    25    A    A  0.042309  0.350105  0.666938  0.692580
# 219  302  100.0    11    A    A  0.787529  1.068868  0.906396  0.772993
# 278  378  100.0    18    A    A  0.229257  0.184127 -0.028095 -0.306684
# 297  405  100.0     9    C    C  0.289935  0.372887  0.209948  0.113607
# 328  443  100.0    14    A    A -0.016786 -0.032609 -0.033291 -0.009160
# 333  450  100.0    13    A    A -0.017561 -0.022654 -0.036706 -0.056104
# 342  460  100.0    11    A    A -0.001735  0.008035  0.012795 -0.000589
# 347  465  100.0    16    A    A  0.015841 -0.018118 -0.065587 -0.096089
# 359  480  100.0     7    A    A -0.045721  0.004311  0.023420 -0.012678
# 375  499  100.0    10    A    A  0.078533  0.119572  0.114162  0.070993
# 378  504  100.0     9    C    C  0.043491  0.042569 -0.004198 -0.060930
# 385  512  100.0    13    C    C -0.023875  0.003101  0.008969 -0.008903
# 411  545  100.0     9    A    C -0.049295 -0.112124 -0.147207 -0.124787
# 489  649  100.0    16    A    A  0.093181 -0.513535  0.082623  1.030178
# 581  774  100.0    21    A    A -0.496989 -0.557056 -0.411464 -0.130304
#
#       t5_2001  ...  t106_9170  t107_9170  t108_9170  t109_9170  t110_9170  \
# 12  -0.240151  ...   1.003227   1.250341   1.702322   2.035567   1.915570
# 28  -0.038158  ...   0.139187   0.143840  -0.086855  -0.439159  -0.714117
# 40   0.286841  ...  -0.965176  -0.506124   0.209764   1.046412   1.756367
# 43  -0.242717  ...  -0.221673   0.275622   0.218207  -0.330875  -0.924717
# 64  -1.720322  ...  17.018944  12.917166  15.140665  20.089666  17.720457
# 69  -2.878236  ...  -5.309491 -14.874697 -15.505020  -7.445506   1.783753
# 72   3.581494  ...  12.147596   6.219250  -0.341131  -2.715621  -0.939410
# 121  2.219596  ...  -3.818442   6.657434  13.913865  11.425905   2.044530
# 176  0.360007  ...  -0.940806  -3.897985  -5.170696  -3.073914   1.040760
# 198  0.269116  ...   5.974799   4.194940   0.884115   0.867618   5.236758
# 219  1.114245  ...  -0.308414  -1.709588  -2.536183  -2.184106  -1.163508
# 278 -0.482384  ...   1.544462   2.694805   2.259744   0.456388  -1.628128
# 297  0.292609  ...   0.770666   1.421493   1.344292   1.261641   1.545040
# 328  0.028118  ...   0.063570   0.085593   0.013788  -0.152260  -0.310912
# 333 -0.055374  ...   0.099973   0.062197   0.037471   0.071302   0.157374
# 342 -0.026571  ...   0.126672   0.215340   0.221587   0.127277  -0.003793
# 347 -0.084769  ...  -0.629238  -0.323387   0.102369   0.313739   0.218874
# 359 -0.069344  ...   0.162016   0.100090   0.098659   0.173126   0.246725
# 375  0.015833  ...  -0.018022  -0.078753  -0.078578   0.065800   0.224337
# 378 -0.085929  ...   0.090168   0.051444  -0.094922  -0.231116  -0.280227
# 385 -0.023638  ...   0.012724   0.118894   0.175911   0.117620  -0.005854
# 411 -0.063856  ...  -0.124035   0.011088   0.065702   0.061919   0.071869
# 489  0.775898  ...  -2.144431  -6.279945  -0.877378   4.909434   0.331636
# 581  0.119724  ...  -0.558128  -2.189988  -3.847928  -4.350260  -2.665650
#
#      t111_9170  t112_9170  t113_9170  t114_9170  t115_9170
# 12    1.285189   0.433016  -0.200682  -0.317398   0.072576
# 28   -0.757148  -0.548288  -0.206343   0.080069   0.144511
# 40    2.040547   1.695298   0.766354  -0.409960  -1.344700
# 43   -1.067618  -0.584479   0.226722   0.768463   0.536608
# 64    4.288623 -11.810506 -18.258877 -11.766512  -1.011262
# 69    5.043738   2.183730  -0.645348   1.944086   8.387974
# 72    0.765364  -1.086358  -5.342284  -7.580034  -5.295020
# 121  -5.044302  -4.298348   1.248278   5.167187   5.212446
# 176   3.722597   2.698064  -0.868383  -3.600314  -3.394384
# 198   9.849600   9.849508   5.047428  -0.048498  -1.442570
# 219  -0.674649  -1.041900  -1.076926   0.506224   3.138302
# 278  -2.889710  -2.917878  -2.043189  -0.850353   0.284994
# 297   1.302025  -0.225847  -1.831964  -1.693149  -0.441266
# 328  -0.315754  -0.124212   0.119911   0.202078   0.055565
# 333   0.219456   0.173570   0.022949  -0.123575  -0.146888
# 342  -0.087372  -0.080501   0.003023   0.108407   0.163544
# 347   0.015461  -0.036661   0.128231   0.334210   0.347230
# 359   0.239538   0.137737  -0.015024  -0.160413  -0.249731
# 375   0.181265  -0.100064  -0.399327  -0.457136  -0.244983
# 378  -0.255428  -0.200869  -0.120171   0.015685   0.199956
# 385  -0.089270  -0.086715  -0.052374  -0.071936  -0.165577
# 411   0.116022   0.152173   0.137877   0.071410  -0.023027
# 489  -5.439502  -2.526252   1.975591   1.489362   0.506980
# 581   0.739130   3.961018   5.173604   4.019330   1.588023
#
# [24 rows x 13345 columns]

# %%
m=np.zeros((99,6670))
for v in tqdm(range(len(target_values))):
    corr=[]
    for i in range(0,116):
        roi_i=train_df[train_df['y']==target_values[v]].iloc[:,5+i*115:5+(i+1)*115]
        for j in range(i+1,116):
            roi_j=train_df[train_df['y']==target_values[v]].iloc[:,5+(j)*115:5+(j+1)*115]
            corr.append(pearsonr(roi_i.values.flatten(),roi_j.values.flatten())[0])
    m[v]=corr
# Out:
# 100%|██████████| 99/99 [50:34<00:00, 30.65s/it]

# %%
np.corrcoef(roi1.values.flatten(),roi2.values.flatten(),rowvar=False)
# Out:
# array([[1.        , 0.17141558],
#        [0.17141558, 1.        ]])

# %%
pearsonr(roi1.values.flatten(),roi2.values.flatten())[0]
# Out:
# 0.17141557728377357

# %%
m
# Out:
# array([[ 0.35348904, -0.12868225, -0.3198488 , ...,  0.6273099 ,
#          0.49386013,  0.76250772],
#        [ 0.26627036,  0.21517651, -0.32456209, ...,  0.61011662,
#          0.59598828,  0.75933304],
#        [ 0.17685979,  0.36812398,  0.1290388 , ...,  0.30938017,
#          0.35665474,  0.51019151],
#        ...,
#        [ 0.43090855, -0.21775683, -0.40646318, ...,  0.12723632,
#         -0.13741944,  0.38419469],
#        [ 0.64870765,  0.04161721,  0.42212238, ...,  0.30222485,
#          0.11180946, -0.00890194],
#        [ 0.56565346,  0.19488014, -0.27836674, ...,  0.39482357,
#          0.08480124,  0.32115026]])

# %%
columns=[f'ROI{i}-ROI{j}'  for i in range(1,116) for j in range (i+1,117) ]

# %%
def get_corr(row,test=False):
    if test:
        brain = np.array(row[4:])
    else:
        brain = np.array(row[5:])
    brain = brain.reshape((116, 115)).astype(float)
    corr = np.corrcoef(brain)
    flat = corr[np.triu_indices(corr.shape[0], 1)]
    return flat.tolist()

# %%
corr=train_df.progress_apply(lambda x :get_corr(x),axis=1)
# Out:
#   0%|          | 1/600 [00:01<11:29,  1.15s/it]C:\Users\Nicola\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\Nicola\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 100%|██████████| 600/600 [00:13<00:00, 43.42it/s]

# %%
#corr_df=pd.DataFrame(np.array(corr.values.tolist()),columns=columns).fillna(0)
corr_df=pd.DataFrame(m,columns=columns).fillna(0)
#new_train=corr_df
#new_train['var1']=train_df['var1']
#new_train['y']=train_df['y']

# %%
corr_df
# Out:
#     ROI1-ROI2  ROI1-ROI3  ROI1-ROI4  ROI1-ROI5  ROI1-ROI6  ROI1-ROI7  \
# 0    0.353489  -0.128682  -0.319849  -0.324166  -0.246387  -0.025520
# 1    0.266270   0.215177  -0.324562   0.035001  -0.268579   0.299189
# 2    0.176860   0.368124   0.129039   0.042282  -0.109159   0.320363
# 3    0.385438   0.128242  -0.336238  -0.117699  -0.216569  -0.300985
# 4    0.288994   0.126783  -0.036986  -0.107399  -0.018702   0.093512
# ..        ...        ...        ...        ...        ...        ...
# 94  -0.115663   0.351149  -0.038836   0.223067   0.004195   0.319957
# 95   0.477742  -0.062977   0.038081  -0.019106   0.193596  -0.046278
# 96   0.430909  -0.217757  -0.406463  -0.127794  -0.122476  -0.223247
# 97   0.648708   0.041617   0.422122   0.218517  -0.010028   0.198131
# 98   0.565653   0.194880  -0.278367   0.213362   0.139202   0.108711
#
#     ROI1-ROI8  ROI1-ROI9  ROI1-ROI10  ROI1-ROI11  ...  ROI112-ROI114  \
# 0   -0.360514  -0.153844   -0.231056    0.406997  ...       0.349207
# 1   -0.011791  -0.092059   -0.311974    0.525294  ...       0.410321
# 2    0.052695  -0.007191   -0.115823    0.438331  ...       0.105945
# 3   -0.291991  -0.028831    0.049166    0.264095  ...       0.129105
# 4   -0.132265   0.072785   -0.027129    0.206432  ...       0.412209
# ..        ...        ...         ...         ...  ...            ...
# 94   0.030517   0.159190    0.073564    0.437765  ...       0.318938
# 95  -0.093730   0.160723    0.030468    0.343544  ...       0.283919
# 96  -0.346684  -0.108791   -0.248721    0.258565  ...      -0.047842
# 97   0.160266  -0.095230   -0.382416    0.069999  ...       0.480733
# 98  -0.133329   0.349854    0.142841    0.474486  ...       0.168467
#
#     ROI112-ROI115  ROI112-ROI116  ROI113-ROI114  ROI113-ROI115  ROI113-ROI116  \
# 0        0.184093       0.295171       0.598233       0.224943       0.198616
# 1        0.140138       0.134177       0.542688       0.266197       0.232802
# 2        0.015031       0.058321       0.094228       0.005790       0.001743
# 3       -0.086784       0.024874       0.520089       0.097454       0.191578
# 4        0.171462      -0.051080       0.296669       0.199877       0.037061
# ..            ...            ...            ...            ...            ...
# 94       0.059053       0.149123       0.502167      -0.034922       0.009250
# 95       0.236332       0.158249       0.328286      -0.343286      -0.097973
# 96       0.346101       0.146305      -0.278035      -0.062824       0.105871
# 97      -0.041561      -0.119244       0.243030       0.092524       0.197212
# 98      -0.126276       0.226508       0.274061       0.159913       0.056439
#
#     ROI114-ROI115  ROI114-ROI116  ROI115-ROI116      y
# 0        0.627310       0.493860       0.762508  113.0
# 1        0.610117       0.595988       0.759333  119.0
# 2        0.309380       0.356655       0.510192  109.0
# 3        0.496777       0.437103       0.702825  110.0
# 4        0.084179      -0.195883       0.133420  123.0
# ..            ...            ...            ...    ...
# 94       0.179169       0.015129       0.072416  148.0
# 95      -0.050513       0.062323       0.119114  136.0
# 96       0.127236      -0.137419       0.384195   79.0
# 97       0.302225       0.111809      -0.008902   75.0
# 98       0.394824       0.084801       0.321150  133.0
#
# [99 rows x 6671 columns]

# %%
corr_df['y']=target_values

# %%
first_cols = train_df.iloc[:, [1,2,3,4]]

# %%
new_train = first_cols.join(corr_df)

# %%
new_train['var2'].replace({'A':0, 'C':1}, inplace = True)
new_train['var3'].replace({'A':0, 'C':1}, inplace = True)

# %%
new_train
# Out:
#          y  var1  var2  var3  ROI1-ROI2  ROI1-ROI3  ROI1-ROI4  ROI1-ROI5  \
# 0    113.0    19     0     0   0.353489  -0.128682  -0.319849  -0.324166
# 1    119.0    14     1     0   0.266270   0.215177  -0.324562   0.035001
# 2    109.0    13     0     0   0.176860   0.368124   0.129039   0.042282
# 3    110.0    18     0     0   0.385438   0.128242  -0.336238  -0.117699
# 4    123.0    32     0     0   0.288994   0.126783  -0.036986  -0.107399
# ..     ...   ...   ...   ...        ...        ...        ...        ...
# 595  110.0    41     0     0        NaN        NaN        NaN        NaN
# 596  120.0    64     0     0        NaN        NaN        NaN        NaN
# 597   96.0    27     0     0        NaN        NaN        NaN        NaN
# 598  118.0    29     1     0        NaN        NaN        NaN        NaN
# 599  110.0    26     0     0        NaN        NaN        NaN        NaN
#
#      ROI1-ROI6  ROI1-ROI7  ...  ROI112-ROI113  ROI112-ROI114  ROI112-ROI115  \
# 0    -0.246387  -0.025520  ...       0.683160       0.349207       0.184093
# 1    -0.268579   0.299189  ...       0.701862       0.410321       0.140138
# 2    -0.109159   0.320363  ...       0.701880       0.105945       0.015031
# 3    -0.216569  -0.300985  ...       0.471972       0.129105      -0.086784
# 4    -0.018702   0.093512  ...       0.502216       0.412209       0.171462
# ..         ...        ...  ...            ...            ...            ...
# 595        NaN        NaN  ...            NaN            NaN            NaN
# 596        NaN        NaN  ...            NaN            NaN            NaN
# 597        NaN        NaN  ...            NaN            NaN            NaN
# 598        NaN        NaN  ...            NaN            NaN            NaN
# 599        NaN        NaN  ...            NaN            NaN            NaN
#
#      ROI112-ROI116  ROI113-ROI114  ROI113-ROI115  ROI113-ROI116  \
# 0         0.295171       0.598233       0.224943       0.198616
# 1         0.134177       0.542688       0.266197       0.232802
# 2         0.058321       0.094228       0.005790       0.001743
# 3         0.024874       0.520089       0.097454       0.191578
# 4        -0.051080       0.296669       0.199877       0.037061
# ..             ...            ...            ...            ...
# 595            NaN            NaN            NaN            NaN
# 596            NaN            NaN            NaN            NaN
# 597            NaN            NaN            NaN            NaN
# 598            NaN            NaN            NaN            NaN
# 599            NaN            NaN            NaN            NaN
#
#      ROI114-ROI115  ROI114-ROI116  ROI115-ROI116
# 0         0.627310       0.493860       0.762508
# 1         0.610117       0.595988       0.759333
# 2         0.309380       0.356655       0.510192
# 3         0.496777       0.437103       0.702825
# 4         0.084179      -0.195883       0.133420
# ..             ...            ...            ...
# 595            NaN            NaN            NaN
# 596            NaN            NaN            NaN
# 597            NaN            NaN            NaN
# 598            NaN            NaN            NaN
# 599            NaN            NaN            NaN
#
# [600 rows x 6674 columns]

# %%
new_train.groupby('y').size().sort_values(ascending=False)
# Out:
# y
# 100.0    24
# 113.0    20
# 109.0    19
# 119.0    18
# 108.0    17
#          ..
# 112.5     1
# 114.5     1
# 115.5     1
# 121.5     1
# 148.0     1
# Length: 99, dtype: int64

# %%
new_train=new_train.groupby('y').mean().reset_index()

# %%
new_train=corr_df

# %% [markdown]
# # Train

# %% [markdown]
# ## Linear Regession

# %%
reg = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(new_train.drop(columns='y'), new_train['y'], test_size=0.25, random_state=42)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X_test)

# %%
mean_squared_error(y_test, y_pred,squared=False)
# Out:
# 21.306007265538923

# %% [markdown]
# ## SVR

# %%
params = [{'kernel' : ['poly'],
        'C' : [1,5,10],
        'degree' : [2,3,4]}]
        #'coef0' : [0.01,10,0.5],
        #'gamma' : ('auto','scale')}]

# %%
svr_reg=SVR()
grids = GridSearchCV(svr_reg,params,cv=3,verbose=5,n_jobs=-1)
grids.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# GridSearchCV(cv=3, estimator=SVR(), n_jobs=-1,
#              param_grid=[{'C': [1, 5, 10], 'degree': [2, 3, 4],
#                           'kernel': ['poly']}],
#              verbose=5)

# %%
grids.best_params_
# Out:
# {'C': 10, 'degree': 2, 'kernel': 'poly'}

# %%
y_pred=grids.predict(X_test)

# %%
mean_squared_error(y_test, y_pred,squared=False)
# Out:
# 19.71655673751547

# %%
#retrain on all dataset
svr_reg=SVR(C= 10, degree= 2, kernel= 'poly')
svr_reg.fit(new_train.drop(columns='y'),new_train['y'])
# Out:
# SVR(C=10, degree=2, kernel='poly')

# %%
y_pred=svr_reg.predict(X_test)

# %%
mean_squared_error(y_test, y_pred,squared=False)
# Out:
# 12.329986536509008

# %% [markdown]
# ## K-neigbors regression

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
for k in range(30,45):
    neigh = KNeighborsRegressor(n_neighbors=k,weights='uniform').fit(X_train, y_train)
    y_pred=neigh.predict(X_test)
    print(k,mean_squared_error(y_test, y_pred,squared=False))
# Out:
# 30 19.33288476491114
# 31 19.654053551869932
# 32 19.68385184453236
# 33 19.75501052319006
# 34 19.811072844912662
# 35 19.763941191689764
# 36 19.613052508564383
# 37 19.58352567136378
# 38 19.585158006189886
# 39 19.565232685711212
# 40 19.55707608514115
# 41 19.579886394448568
# 42 19.660283179391836
# 43 19.644385923805764
# 44 19.66006342838864

# %%
neigh = KNeighborsRegressor(n_neighbors=33,weights='distance',p=2).fit(X_train, y_train)

# %%
y_pred=neigh.predict(X_test)

# %%
mean_squared_error(y_test, y_pred,squared=False)
# Out:
# 19.73072846541149

# %%
neigh = KNeighborsRegressor(n_neighbors=33,weights='distance',p=2).fit(new_train.drop(columns='y'),new_train['y'])

# %%
y_pred=neigh.predict(X_test)

# %%
mean_squared_error(y_test, y_pred,squared=False)
# Out:
# 2.0380742626957553e-05

# %% [markdown]
# # Test

# %%
test_df=pd.read_csv('./Data/test.csv')

# %%
test_df
# Out:
#       id  var1 var2 var3   t1_2001   t2_2001   t3_2001   t4_2001   t5_2001  \
# 0     17    32    A    A -0.350440 -0.222368  0.023356  0.243820  0.307884
# 1     19    11    C    A -0.637826 -0.626851 -0.360784  0.030366  0.336757
# 2     25    17    A    C -0.012941 -0.104797 -0.236863 -0.323248 -0.289526
# 3     32    17    A    C  0.090513  0.210141  0.258353  0.176808 -0.021250
# 4     33    16    A    C  0.020757  0.004422  0.048168  0.217449  0.499191
# ..   ...   ...  ...  ...       ...       ...       ...       ...       ...
# 194  777    20    A    C  0.196767  0.279578  0.269504  0.142366 -0.050581
# 195  783    24    A    C  0.166928  0.062544 -0.064816 -0.223924 -0.397589
# 196  784    24    A    C  0.467909  0.601598  0.466428  0.064870 -0.453154
# 197  792    29    C    C  0.158687  0.187958  0.187666  0.168700  0.137513
# 198  796    35    A    A -0.236773 -0.267845 -0.108305  0.141632  0.310586
#
#       t6_2001  ...  t106_9170  t107_9170  t108_9170  t109_9170  t110_9170  \
# 0    0.181462  ...  -0.249206  -0.299956  -0.230605  -0.002176   0.307232
# 1    0.405507  ...   0.747080   1.451542   1.888522   1.843617   1.353949
# 2   -0.127867  ...  -2.263840  -2.082246  -1.299818  -0.087112   1.200546
# 3   -0.246477  ...  -2.662342  -1.246634   0.756969   2.115026   2.007031
# 4    0.774152  ...   0.000000   0.000000   0.000000   0.000000   0.000000
# ..        ...  ...        ...        ...        ...        ...        ...
# 194 -0.192273  ...   1.501500   0.315651  -0.438466  -0.390447   0.203565
# 195 -0.477872  ...   0.998999   2.150780   1.765160   0.167519  -1.398137
# 196 -0.874220  ...   4.963199   1.800244  -2.997877  -5.256964  -2.305884
# 197  0.109296  ...  -2.660509  -1.084989   0.932748   2.014907   1.678764
# 198  0.313349  ...   0.010158   0.408345  -0.480362  -1.950726  -2.116528
#
#      t111_9170  t112_9170  t113_9170  t114_9170  t115_9170
# 0     0.574038   0.719488   0.739103   0.657216   0.466077
# 1     0.721757   0.341038   0.461075   1.052172   1.853388
# 2     2.217524   2.777598   2.863644   2.528300   1.804936
# 3     0.606600  -1.034530  -1.731524  -1.012911   0.541681
# 4     0.000000   0.000000   0.000000   0.000000   0.000000
# ..         ...        ...        ...        ...        ...
# 194   1.092143   1.984272   2.303799   1.587597   0.184648
# 195  -2.035133  -1.780128  -1.156148  -0.511489   0.100604
# 196   3.395893   5.967640   2.081252  -5.207866  -9.263192
# 197   0.401733  -0.877058  -1.297012  -0.560106   0.733061
# 198  -0.442166   1.441936   1.849335   1.124896   0.849227
#
# [199 rows x 13344 columns]

# %%
corr_test=test_df.progress_apply(lambda row:get_corr(row,test=True),axis=1)
# Out:
#   2%|▏         | 3/199 [00:00<00:28,  6.80it/s]C:\Users\Nicola\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\Nicola\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 100%|██████████| 199/199 [00:05<00:00, 36.06it/s]

# %%
test_final_df=pd.DataFrame(np.array(corr_test.values.tolist()),columns=columns).fillna(0)

# %%
test_final_df
# Out:
#      ROI1-ROI2  ROI1-ROI3  ROI1-ROI4  ROI1-ROI5  ROI1-ROI6  ROI1-ROI7  \
# 0     0.574820  -0.184674   0.335784  -0.433897  -0.314960   0.121238
# 1     0.459187   0.091974  -0.012738   0.018270  -0.144327   0.286588
# 2     0.318010   0.118248  -0.275287   0.067088   0.031507  -0.158764
# 3     0.405577  -0.424435  -0.260486  -0.053301   0.118364  -0.187334
# 4     0.531680   0.145877  -0.131794   0.361544   0.015393   0.055204
# ..         ...        ...        ...        ...        ...        ...
# 194   0.217994   0.204179  -0.118850   0.250223   0.456717  -0.195145
# 195   0.465376   0.038288  -0.065834  -0.123540  -0.223827   0.372467
# 196   0.320433  -0.058686  -0.264435  -0.292921  -0.012648  -0.363793
# 197   0.550265  -0.386250  -0.283560   0.059427   0.095853  -0.092002
# 198   0.447044  -0.015609   0.000369  -0.003614  -0.022943   0.049551
#
#      ROI1-ROI8  ROI1-ROI9  ROI1-ROI10  ROI1-ROI11  ...  ROI112-ROI113  \
# 0    -0.304749  -0.360175   -0.213842    0.592588  ...       0.188771
# 1    -0.024430   0.003806   -0.102631   -0.192910  ...       0.395746
# 2    -0.122662   0.233291    0.070906    0.441458  ...       0.656703
# 3    -0.161422  -0.307382   -0.090365    0.439814  ...       0.560449
# 4    -0.210112   0.204085    0.027663    0.721721  ...       0.003357
# ..         ...        ...         ...         ...  ...            ...
# 194  -0.325952  -0.053743   -0.012564    0.794479  ...       0.218118
# 195  -0.039882  -0.101934   -0.115844    0.628183  ...       0.453787
# 196  -0.426708   0.040388   -0.286963    0.561433  ...       0.072454
# 197   0.283123   0.147292   -0.060154    0.400976  ...       0.114647
# 198  -0.308286   0.024050   -0.128347    0.187289  ...       0.718296
#
#      ROI112-ROI114  ROI112-ROI115  ROI112-ROI116  ROI113-ROI114  \
# 0         0.237508       0.273457       0.225723      -0.060189
# 1        -0.245494       0.173441       0.203784      -0.069734
# 2         0.428289       0.123900       0.090384       0.504827
# 3         0.255396      -0.304971      -0.070677       0.186580
# 4         0.000000       0.000000       0.000000       0.000000
# ..             ...            ...            ...            ...
# 194       0.021160       0.018531       0.039184      -0.006917
# 195       0.121769       0.407962       0.322393       0.502507
# 196      -0.090642       0.058275       0.047026       0.451872
# 197       0.535039       0.289765       0.529971       0.317849
# 198       0.152719      -0.237177       0.161192       0.332678
#
#      ROI113-ROI115  ROI113-ROI116  ROI114-ROI115  ROI114-ROI116  ROI115-ROI116
# 0         0.135940      -0.068397       0.239504       0.221618      -0.186755
# 1         0.214056       0.230202       0.037493       0.031108       0.125471
# 2         0.382075       0.136943       0.402817       0.237602       0.293227
# 3        -0.116094       0.077223       0.041814      -0.004182       0.266954
# 4         0.000000       0.000000       0.000000       0.000000       0.000000
# ..             ...            ...            ...            ...            ...
# 194      -0.157338      -0.094451       0.751545       0.652086       0.765714
# 195       0.234785       0.260871       0.272752       0.113825       0.565614
# 196       0.040126       0.278858       0.593402       0.321660       0.652692
# 197       0.188834      -0.064073       0.547437       0.426339       0.495522
# 198      -0.231984       0.114105       0.023730       0.069423       0.278818
#
# [199 rows x 6670 columns]

# %%
test_df
# Out:
#       id  var1 var2 var3   t1_2001   t2_2001   t3_2001   t4_2001   t5_2001  \
# 0     17    32    A    A -0.350440 -0.222368  0.023356  0.243820  0.307884
# 1     19    11    C    A -0.637826 -0.626851 -0.360784  0.030366  0.336757
# 2     25    17    A    C -0.012941 -0.104797 -0.236863 -0.323248 -0.289526
# 3     32    17    A    C  0.090513  0.210141  0.258353  0.176808 -0.021250
# 4     33    16    A    C  0.020757  0.004422  0.048168  0.217449  0.499191
# ..   ...   ...  ...  ...       ...       ...       ...       ...       ...
# 194  777    20    A    C  0.196767  0.279578  0.269504  0.142366 -0.050581
# 195  783    24    A    C  0.166928  0.062544 -0.064816 -0.223924 -0.397589
# 196  784    24    A    C  0.467909  0.601598  0.466428  0.064870 -0.453154
# 197  792    29    C    C  0.158687  0.187958  0.187666  0.168700  0.137513
# 198  796    35    A    A -0.236773 -0.267845 -0.108305  0.141632  0.310586
#
#       t6_2001  ...  t106_9170  t107_9170  t108_9170  t109_9170  t110_9170  \
# 0    0.181462  ...  -0.249206  -0.299956  -0.230605  -0.002176   0.307232
# 1    0.405507  ...   0.747080   1.451542   1.888522   1.843617   1.353949
# 2   -0.127867  ...  -2.263840  -2.082246  -1.299818  -0.087112   1.200546
# 3   -0.246477  ...  -2.662342  -1.246634   0.756969   2.115026   2.007031
# 4    0.774152  ...   0.000000   0.000000   0.000000   0.000000   0.000000
# ..        ...  ...        ...        ...        ...        ...        ...
# 194 -0.192273  ...   1.501500   0.315651  -0.438466  -0.390447   0.203565
# 195 -0.477872  ...   0.998999   2.150780   1.765160   0.167519  -1.398137
# 196 -0.874220  ...   4.963199   1.800244  -2.997877  -5.256964  -2.305884
# 197  0.109296  ...  -2.660509  -1.084989   0.932748   2.014907   1.678764
# 198  0.313349  ...   0.010158   0.408345  -0.480362  -1.950726  -2.116528
#
#      t111_9170  t112_9170  t113_9170  t114_9170  t115_9170
# 0     0.574038   0.719488   0.739103   0.657216   0.466077
# 1     0.721757   0.341038   0.461075   1.052172   1.853388
# 2     2.217524   2.777598   2.863644   2.528300   1.804936
# 3     0.606600  -1.034530  -1.731524  -1.012911   0.541681
# 4     0.000000   0.000000   0.000000   0.000000   0.000000
# ..         ...        ...        ...        ...        ...
# 194   1.092143   1.984272   2.303799   1.587597   0.184648
# 195  -2.035133  -1.780128  -1.156148  -0.511489   0.100604
# 196   3.395893   5.967640   2.081252  -5.207866  -9.263192
# 197   0.401733  -0.877058  -1.297012  -0.560106   0.733061
# 198  -0.442166   1.441936   1.849335   1.124896   0.849227
#
# [199 rows x 13344 columns]

# %%
first_cols_test = test_df.iloc[:, [1,2,3]]
new_test = first_cols_test.join(test_final_df)
new_test['var2'].replace({'A':0, 'C':1}, inplace = True)
new_test['var3'].replace({'A':0, 'C':1}, inplace = True)

# %%
new_test
# Out:
#      var1  var2  var3  Roi1-Roi2  Roi1-Roi3  Roi1-Roi4  Roi1-Roi5  Roi1-Roi6  \
# 0      32     0     0   0.574820  -0.184674   0.335784  -0.433897  -0.314960
# 1      11     1     0   0.459187   0.091974  -0.012738   0.018270  -0.144327
# 2      17     0     1   0.318010   0.118248  -0.275287   0.067088   0.031507
# 3      17     0     1   0.405577  -0.424435  -0.260486  -0.053301   0.118364
# 4      16     0     1   0.531680   0.145877  -0.131794   0.361544   0.015393
# ..    ...   ...   ...        ...        ...        ...        ...        ...
# 194    20     0     1   0.217994   0.204179  -0.118850   0.250223   0.456717
# 195    24     0     1   0.465376   0.038288  -0.065834  -0.123540  -0.223827
# 196    24     0     1   0.320433  -0.058686  -0.264435  -0.292921  -0.012648
# 197    29     1     1   0.550265  -0.386250  -0.283560   0.059427   0.095853
# 198    35     0     0   0.447044  -0.015609   0.000369  -0.003614  -0.022943
#
#      Roi1-Roi7  Roi1-Roi8  ...  Roi112-Roi113  Roi112-Roi114  Roi112-Roi115  \
# 0     0.121238  -0.304749  ...       0.188771       0.237508       0.273457
# 1     0.286588  -0.024430  ...       0.395746      -0.245494       0.173441
# 2    -0.158764  -0.122662  ...       0.656703       0.428289       0.123900
# 3    -0.187334  -0.161422  ...       0.560449       0.255396      -0.304971
# 4     0.055204  -0.210112  ...       0.003357       0.000000       0.000000
# ..         ...        ...  ...            ...            ...            ...
# 194  -0.195145  -0.325952  ...       0.218118       0.021160       0.018531
# 195   0.372467  -0.039882  ...       0.453787       0.121769       0.407962
# 196  -0.363793  -0.426708  ...       0.072454      -0.090642       0.058275
# 197  -0.092002   0.283123  ...       0.114647       0.535039       0.289765
# 198   0.049551  -0.308286  ...       0.718296       0.152719      -0.237177
#
#      Roi112-Roi116  Roi113-Roi114  Roi113-Roi115  Roi113-Roi116  \
# 0         0.225723      -0.060189       0.135940      -0.068397
# 1         0.203784      -0.069734       0.214056       0.230202
# 2         0.090384       0.504827       0.382075       0.136943
# 3        -0.070677       0.186580      -0.116094       0.077223
# 4         0.000000       0.000000       0.000000       0.000000
# ..             ...            ...            ...            ...
# 194       0.039184      -0.006917      -0.157338      -0.094451
# 195       0.322393       0.502507       0.234785       0.260871
# 196       0.047026       0.451872       0.040126       0.278858
# 197       0.529971       0.317849       0.188834      -0.064073
# 198       0.161192       0.332678      -0.231984       0.114105
#
#      Roi114-Roi115  Roi114-Roi116  Roi115-Roi116
# 0         0.239504       0.221618      -0.186755
# 1         0.037493       0.031108       0.125471
# 2         0.402817       0.237602       0.293227
# 3         0.041814      -0.004182       0.266954
# 4         0.000000       0.000000       0.000000
# ..             ...            ...            ...
# 194       0.751545       0.652086       0.765714
# 195       0.272752       0.113825       0.565614
# 196       0.593402       0.321660       0.652692
# 197       0.547437       0.426339       0.495522
# 198       0.023730       0.069423       0.278818
#
# [199 rows x 6673 columns]

# %%
plt.hist(new_test.iloc[0,3:]);

# %%
y_pred_test=svr_reg.predict(test_final_df)

# %%
plt.hist(y_pred_test)
# Out:
# (array([ 4.,  5.,  8., 31., 41., 54., 32., 14.,  8.,  2.]),
#  array([100.81918851, 102.35917765, 103.89916679, 105.43915593,
#         106.97914507, 108.51913421, 110.05912335, 111.59911248,
#         113.13910162, 114.67909076, 116.2190799 ]),
#  <BarContainer object of 10 artists>)

# %%
y_pred_test.max()
# Out:
# 116.219079902716

# %%
y_pred_test
# Out:
# array([109.85441777, 108.39277004, 111.08723465, 110.36408987,
#        108.688151  , 109.47698791, 106.21677321, 109.40234782,
#        109.01665127, 108.02039767, 106.54843469, 103.74457317,
#        107.43320198, 109.1642719 , 105.02757663, 113.28616026,
#        107.69783864, 109.46038366, 108.1803827 , 110.99576696,
#        111.48993641, 110.1399893 , 113.58507759, 111.77918267,
#        107.97324133, 110.66118234, 112.14888286, 113.39003528,
#        108.9383404 , 111.48414401, 109.56171593, 109.94991984,
#        111.66532948, 112.4529169 , 109.23789156, 116.2190799 ,
#        105.82084603, 106.35747718, 110.69309037, 105.07860744,
#        110.88979843, 106.10768447, 110.17548194, 108.61296238,
#        102.2785831 , 110.49400332, 112.00868415, 108.97528731,
#        110.65812758, 108.67916757, 107.20407875, 105.75483184,
#        106.8477371 , 107.42875296, 106.4462214 , 110.82386448,
#        110.7565012 , 112.28904521, 108.898604  , 109.21479153,
#        107.73449988, 108.70333854, 109.90669138, 110.0342093 ,
#        109.16419023, 107.66747385, 108.35606306, 109.56714092,
#        107.05407923, 105.44352568, 105.92133897, 109.30129364,
#        107.60245381, 111.30922283, 104.21572225, 107.30657207,
#        107.04904769, 108.61850067, 106.26947789, 106.34264191,
#        110.49058725, 107.61749316, 101.9672512 , 113.0369807 ,
#        108.25560667, 102.04324076, 103.39285454, 106.95756268,
#        106.17278967, 104.85105887, 104.83014076, 100.81918851,
#        107.06880021, 109.91619741, 113.68732025, 113.88389501,
#        111.10512408, 106.21540218, 108.31455939, 115.76281805,
#        108.7888239 , 106.87809616, 107.42891748, 108.87726434,
#        107.86907019, 108.7164559 , 109.32762425, 106.43864571,
#        108.65270186, 107.5900988 , 106.48379896, 108.31866717,
#        109.25328421, 109.31170768, 112.98734591, 112.20200149,
#        110.75168245, 111.65457323, 111.3093269 , 108.54739578,
#        107.13340307, 106.83226526, 109.36324259, 109.99574869,
#        108.29855593, 114.1158713 , 111.15482151, 103.50886935,
#        108.9685677 , 106.75805173, 108.68094533, 107.77734554,
#        112.64943179, 109.22410371, 108.51240797, 110.45514671,
#        110.14345538, 110.63381829, 110.57574603, 109.77401715,
#        110.95046305, 111.43231821, 111.71119756, 111.73350185,
#        111.20193323, 107.80423868, 106.51233381, 107.80522688,
#        111.07590289, 113.26079065, 107.31670836, 109.82984945,
#        108.40793782, 107.96051417, 108.97680922, 109.66349718,
#        105.43925452, 110.58952816, 109.61858575, 111.53695683,
#        105.41009856, 107.71655861, 106.86956102, 109.47231898,
#        106.98897217, 109.81573178, 105.85939967, 108.813128  ,
#        106.64600719, 111.66434215, 108.61836821, 109.03240843,
#        106.02443196, 107.29062148, 103.98403744, 103.89166198,
#        104.36261792, 107.53360138, 106.77887484, 109.53057159,
#        108.80702245, 106.99094426, 107.81084133, 107.35855222,
#        106.06025108, 103.82785307, 109.18260105, 109.12273406,
#        109.49699368, 105.73905069, 108.84826926, 109.03655859,
#        114.12755199, 110.58759711, 110.19326473, 105.97270605,
#        106.71857814, 108.45857898, 107.84990887])

# %%
df_leaderboard=pd.DataFrame({'id':test_df['id'],'target':y_pred_test})

# %%
df_leaderboard
# Out:
#       id      target
# 0     17  109.854418
# 1     19  108.392770
# 2     25  111.087235
# 3     32  110.364090
# 4     33  108.688151
# ..   ...         ...
# 194  777  110.193265
# 195  783  105.972706
# 196  784  106.718578
# 197  792  108.458579
# 198  796  107.849909
#
# [199 rows x 2 columns]

# %%
df_leaderboard
# Out:
#       id      target
# 0     17  110.158718
# 1     19  107.920292
# 2     25  108.159483
# 3     32  104.923576
# 4     33  106.752830
# ..   ...         ...
# 194  777  113.772811
# 195  783  112.309465
# 196  784  113.409241
# 197  792  114.279185
# 198  796  108.703676
#
# [199 rows x 2 columns]

# %%
df_leaderboard.to_csv('G14_11_crazy_preprocessing',index=False)
